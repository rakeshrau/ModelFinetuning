# %% [markdown]
# ## Installing Necessary Libraries

# %%
# !pip install wandb trl transformers accelerate peft datasets bitsandbytes einops pdfquery timeout-decorator
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: trl in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.41.3.post2)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: pdfquery in /usr/local/lib/python3.10/dist-packages (0.4.3)
# Requirement already satisfied: timeout-decorator in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.40)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.39.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.1.0+cu121)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from trl) (1.23.5)
# Requirement already satisfied: tyro>=0.5.11 in /usr/local/lib/python3.10/dist-packages (from trl) (0.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: cssselect>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pdfquery) (1.2.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from pdfquery) (5.2.0)
# Requirement already satisfied: lxml>=3.0 in /usr/local/lib/python3.10/dist-packages (from pdfquery) (4.9.3)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from pdfquery) (20221105)
# Requirement already satisfied: pyquery>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from pdfquery) (2.0.0)
# Requirement already satisfied: roman>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pdfquery) (4.1)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.11.17)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.1.0)
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (1.6.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->pdfquery) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->pdfquery) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pdfquery) (2.21)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import userdata
wandb_secret = userdata.get('wandb')

# %%
import os
# Set the environment variable
os.environ['wandb_secret'] = wandb_secret

# %%
# !wandb login $wandb_secret
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import wandb
wandb.init()
# Out:
# wandb: Currently logged in as: imsamread81. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/content/wandb/run-20231216_203111-8s1sogya</code>
# Syncing run <strong><a href='https://wandb.ai/imsamread81/uncategorized/runs/8s1sogya' target="_blank">smart-silence-83</a></strong> to <a href='https://wandb.ai/imsamread81/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/imsamread81/uncategorized' target="_blank">https://wandb.ai/imsamread81/uncategorized</a>
#  View run at <a href='https://wandb.ai/imsamread81/uncategorized/runs/8s1sogya' target="_blank">https://wandb.ai/imsamread81/uncategorized/runs/8s1sogya</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/imsamread81/uncategorized/runs/8s1sogya?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

# model_name = "NousResearch/Llama-2-7b-hf"
model_name = "NousResearch/Llama-2-7b-chat-hf"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
import transformers
from datasets import Dataset

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import gc
import time
import timeout_decorator

# %%
@timeout_decorator.timeout(60)
def predict_response(text):
    predictions = pipeline(text, max_length=300,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id)

    # Print the predictions
    # print(predictions)
    mresponse = predictions[0]['generated_text']
    return mresponse

# %%
from datasets import load_dataset
dataset = load_dataset("abhishek-mungoli/srk_wittiness")
df = pd.DataFrame({'question': dataset['train']['question'],'response': dataset['train']['response']})
display(df)
# Out:
# Downloading readme:   0%|          | 0.00/334 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/58.7k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
#                                               question  \
# 0    If you could erase one project from your caree...
# 1    Can you share a moment when you doubted your o...
# 2    What's the most significant criticism you've r...
# 3    If you could trade talents with another celebr...
# 4    How do you handle negative feedback or critici...
# ..                                                 ...
# 206                            What books do you read?
# 207  What things do you want to change in the indus...
# 208        Could you live a good life without privacy?
# 209               Tell us about your new family movie.
# 210                  What’s your favorite Summer look?
#
#                                               response
# 0    Well, I would erase the project of trying to g...
# 1    Well, there was this one time when I doubted m...
# 2    Well, someone once told me I overact. I took i...
# 3    Well, I would trade talents with Leonardo DiCa...
# 4    Well, I treat it like I treat my morning alarm...
# ..                                                 ...
# 206  Well, I mostly read scripts. They're like nove...
# 207  Well, I would like to change the perception th...
# 208  Well, I've been living in the public eye for s...
# 209  Well, it's a movie where I play a father who i...
# 210  Well, my favorite summer look is a bit of swea...
#
# [211 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop("response", axis=1)
y = df["response"]

# Split the data into a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.18, random_state=42)

# Create new DataFrames df_train and df_test
df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)


print( df_train.shape, df_test.shape )
# Out:
# (173, 2) (38, 2)

# %%
df_train['text'] = df_train.apply(lambda row: f"Question: {row['question']}\nShah Rukh Khan: {row['response']}", axis=1)
df_test['text'] = df_test.apply(lambda row: f"Question: {row['question']}\nShah Rukh Khan: ", axis=1)

# %%
display(df_train)
# Out:
#                                               question  \
# 189                         Have you ever dated a fan?
# 93   If you had to spend a day as an inanimate obje...
# 115  You're the captain of a spaceship, and you hav...
# 163  Were you a part of any school clubs or organiz...
# 195       What’s a message you want to tell your fans?
# ..                                                 ...
# 106  If you could communicate with extraterrestrial...
# 14   How do you handle situations where you strongl...
# 92   In a zombie apocalypse, which three celebritie...
# 179  What's a lesson you learned from a friendship ...
# 102  Imagine you're the captain of a spaceship expl...
#
#                                               response  \
# 189  Well, I've been dating my biggest fan for over...
# 93   I would choose to be a mirror. That way, I cou...
# 115  Well, I would definitely choose Iron Man for h...
# 163  Well, I was a part of the 'I'm too cool for sc...
# 195  Well, I would say, keep loving me as you do, a...
# ..                                                 ...
# 106  Well, I'd probably ask them if they've seen an...
# 14   Well, I usually handle it by reminding myself ...
# 92   Well, I would choose Bear Grylls for survival ...
# 179  Well, I learned that if you want to keep your ...
# 102  Well, my mission would be to find a planet whe...
#
#                                                   text
# 189  Question: Have you ever dated a fan?\nShah Ruk...
# 93   Question: If you had to spend a day as an inan...
# 115  Question: You're the captain of a spaceship, a...
# 163  Question: Were you a part of any school clubs ...
# 195  Question: What’s a message you want to tell yo...
# ..                                                 ...
# 106  Question: If you could communicate with extrat...
# 14   Question: How do you handle situations where y...
# 92   Question: In a zombie apocalypse, which three ...
# 179  Question: What's a lesson you learned from a f...
# 102  Question: Imagine you're the captain of a spac...
#
# [173 rows x 3 columns]

# %%
df_test.shape
# Out:
# (38, 3)

# %%
infer_limit = 30
mix = 0
solutions = []
for ix, row in df_test.iterrows():
    try:
        text = f"Shah Rukh Khan is an actor known for his witty responses. How would he reply with wit and humor to the following question - {row['question']}"
        solutions.append([row['question'], predict_response(text), row['response']])
        print(mix, "Done")
    except Exception as e:
        print("An exception occurred:", str(e))
        try:
            solutions.append([row['question'], predict_response(text), row['response']])
            print(mix, "Done")
        except Exception as e:
            print("An exception occurred:", str(e))
    # if mix > infer_limit:
    #     break
    mix += 1

df_soln = pd.DataFrame(solutions, columns=['question','llama_response', 'chatgpt_response'])

display(df_soln)

df_soln.to_csv('/content/drive/MyDrive/Colab Notebooks/output_unmerge.csv', index=False, header=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# An exception occurred: 'Timed Out'
# 0 Done
# 1 Done
# An exception occurred: 'Timed Out'
# 2 Done
# 3 Done
# An exception occurred: 'Timed Out'
# 4 Done
# An exception occurred: 'Timed Out'
# An exception occurred: 'Timed Out'
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# An exception occurred: 'Timed Out'
# An exception occurred: 'Timed Out'
# 7 Done
# 8 Done
# 9 Done
# 10 Done
# 11 Done
# An exception occurred: 'Timed Out'
# 12 Done
# An exception occurred: 'Timed Out'
# 13 Done
# 14 Done
# 15 Done
# 16 Done
# 17 Done
# An exception occurred: 'Timed Out'
# An exception occurred: 'Timed Out'
# 19 Done
# An exception occurred: 'Timed Out'
# 20 Done
# 21 Done
# 22 Done
# An exception occurred: 'Timed Out'
# An exception occurred: 'Timed Out'
# 24 Done
# 25 Done
# An exception occurred: 'Timed Out'
# 26 Done
# An exception occurred: 'Timed Out'
# An exception occurred: 'Timed Out'
# 28 Done
# 29 Done
# An exception occurred: 'Timed Out'
# An exception occurred: 'Timed Out'
# 3   Well, I've always believed in the philosophy o...
# 4   Well, I believe I've worked hard for my accola...
# 5   Well, I would choose the day I was born. I mea...
# 6   Well, I would probably start by convincing my ...
# 7   Well, firstly, I would wish for an unlimited s...
# 8   I would tell my younger self, 'Don't worry, yo...
# 9   Well, every project I do becomes memorable bec...
# 10  Well, I once tried to study for an entire nigh...
# 11  Well, I believe it's because my performances a...
# 12  Well, some people think I'm a vampire because ...
# 13  Well, I was heavily influenced by the sound of...
# 14  Well, as a child, I used to think that birthda...
# 15  Well, I don't really manage it. I just let it ...
# 16  Well, I've always been a lover, not a fighter....
# 17  Well, I guess it's because I'm such a good act...
# 18  Well, I'm an actor, not a magician. I can't ma...
# 19  Yes, indeed. They used to call me 'Battery'. N...
# 20  Well, my parents always told me to brush my te...
# 21  Well, they taught me that if you can't find a ...
# 22  Well, there was this one time when I was tryin...
# 23  Well, I would love to experience the joy of be...
# 24  Well, I once had to do a project on humility. ...
# 25  Well, the target would definitely be the secre...
# 26  Well, if being surrounded by talented people, ...
# 27  Well, I always say, I'm like a Cadbury chocola...
# 28  Well, I was a bit of both. I followed the rule...
# 29  Well, I would probably learn the art of making...

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(df_train),
})

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    # target_modules=["q_proj","v_proj"]
    target_modules=['q_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj', 'k_proj', 'v_proj'] # Choose all linear layers from the model
)

# %%
# !rm -r ./results
# Out:
# rm: cannot remove './results': No such file or directory

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 2
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 5
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 300
# max_steps = 3
warmup_ratio = 0.03
lr_scheduler_type = "constant"
save_total_limit = 1

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
    ddp_find_unused_parameters=False,
    save_total_limit = save_total_limit
)

# %%
from trl import SFTTrainer

max_seq_length = 300

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    # train_dataset=data['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    # dataset_text_field="prediction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# Map:   0%|          | 0/173 [00:00<?, ? examples/s]

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %%
# !export TORCH_DISTRIBUTED_DEBUG=INFO

# %%
import torch
torch.cuda.empty_cache()

import gc
gc.collect()
# Out:
# 227

# %%
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 57:49, Epoch 13/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.016300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.076800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.085700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.854500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.059000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.649000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.541800</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.735700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.656000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.797000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.362300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.527400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.393200</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.499100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.500800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.266300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.330000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.236900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.207500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.268600</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.138100</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.093400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.109400</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.095900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.957700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.028500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.953200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.950000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.944700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.958300</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.805300</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.021400</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.099100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.985800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.041300</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.868000</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.876800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.911100</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.855300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.843500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.866200</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.898100</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.952300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.858300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.615000</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.676600</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.562700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.461600</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.577600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.662500</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.488900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.531400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.513700</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.534200</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.680300</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.471000</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.572600</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.483700</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.531000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.586200</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.552400</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.599300</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.510300</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.512000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.502700</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.462100</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.291600</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.328100</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.231000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.200900</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.288800</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.254500</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.193400</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.259100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.235000</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.309400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.267300</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.266800</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.233300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.222500</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.304400</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.265600</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.190800</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.219700</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.257800</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.250600</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.259700</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.193400</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.138700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.133800</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.146000</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.168800</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.180800</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.135200</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.150700</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.163500</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.172400</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.149200</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.144200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.138300</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.184900</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.165100</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.138500</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.182500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.169900</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.175700</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.203200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.213100</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.162300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.111800</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.106800</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.114300</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.129300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.122000</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.116900</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.139600</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.147600</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.143700</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.123400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.130000</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.125300</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.177000</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.135500</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.134400</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.115900</td>
#     </tr>
#     <tr>
#       <td>126<
# TrainOutput(global_step=300, training_loss=0.3170351559172074, metrics={'train_runtime': 3473.9084, 'train_samples_per_second': 0.691, 'train_steps_per_second': 0.086, 'total_flos': 8147175234895872.0, 'train_loss': 0.3170351559172074, 'epoch': 13.79})

# %%
trainer.save_model("/content/drive/MyDrive/Colab Notebooks/llamav2-7b-lora-fine-tune_unmerge")

# %%
# adapter_model_name = '/content/drive/MyDrive/Colab Notebooks/llamav2-7b-lora-fine-tune'
# base_model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     quantization_config=bnb_config,
#     trust_remote_code=True
# )

# %%
# from peft import PeftConfig, PeftModel
# final_model = PeftModel.from_pretrained(base_model, adapter_model_name)

# final_model = final_model.merge_and_unload()

# %%
# final_model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/merged_adapters")

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

# %%
@timeout_decorator.timeout(60)
def predict_response_finetuned(text):
    predictions = pipeline(text, max_length=300,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id)

    # Print the predictions
    # print(predictions)
    mresponse = predictions[0]['generated_text']
    return mresponse

# %%
import time

results = []

start_time = time.time()  # Record the start time

mix = 0
solutions = []
for ix, row in df_test.iterrows():
    try:
        # text = f"Shah Rukh Khan is an actor known for his witty responses. How would he reply with wit and humor to the following question - {row['question']}"
        text = row['text']
        solutions.append([row['question'], predict_response_finetuned(text), row['response']])
    except Exception as e:
        print("An exception occurred:", str(e))
        try:
            solutions.append([row['question'], predict_response_finetuned(text), row['response']])
        except Exception as e:
            print("An exception occurred:", str(e))
    # if mix > 2:
    #     break
    mix += 1

# This will print a warning message, but it will be more efficient than calling the pipeline sequentially.

end_time = time.time()  # Record the end time
elapsed_time = end_time - start_time

print("Time taken to run the loop:", elapsed_time/60.0, "minutes")

df_soln = pd.DataFrame(solutions, columns=['question','llama_response', 'chatgpt_response'])

display(df_soln)

df_soln.to_csv('/content/drive/MyDrive/Colab Notebooks/output_finetuned_unmerge.csv', index=False, header=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# An exception occurred: 'Timed Out'
# An exception occurred: 'Timed Out'
# Time taken to run the loop: 15.282626032829285 minutes
#                                              question  \
# 0   What's the most unusual or unexpected source o...
# 1   Did you ever participate in a talent show at s...
# 2   What was your first job, and what did you lear...
# 3   Can you respond to the criticism that your rec...
# 4   Do you think you deserve all the accolades you...
# 5         Could you live a good life without privacy?
# 6   Can you recall a moment when you felt creative...
# 7   If you could relive one day from your childhoo...
# 8   If you had to start your career over, what wou...
# 9   You find a magic lamp with a genie inside. Wha...
# 10  If you could time-travel to your childhood, wh...
# 11                What’s your most memorable project?
# 12  What's the most adventurous thing you did as a...
# 13  Why do you think people question your authenti...
# 14  What's a misconception about you that you find...
# 15                Who were your musical inspirations?
# 16        How did you celebrate birthdays as a child?
# 17  How do you manage the constant comparison to y...
# 18               Tell us about your new family movie.
# 19  Would you rather fight one horse-sized duck or...
# 20  Why do you believe there's a perception that y...
# 21  Can you explain the recent scandalous event in...
# 22                 Did you have a childhood nickname?
# 23                            What books do you read?
# 24  What's a piece of advice from your parents tha...
# 25  What's the most valuable lesson your parents t...
# 26  Can you share a moment when you felt creativel...
# 27  If you had to survive a night in a haunted hou...
# 28  If you could switch lives with a fan for a day...
# 29  What's a school project or assignment you're p...
# 30          Did you have a childhood celebrity crush?
# 31  You're the protagonist in a heist movie. What'...
# 32  If you were a character in a horror movie, wha...
# 33  Do you think your success has made you lose to...
# 34  How do you respond to fans who feel betrayed b...
# 35  What's a quirky habit or talent you had as a c...
# 36  Were you more of a rebellious or rule-abiding ...
# 37  If you had to spend a year in a remote monaste...
#
#                                        llama_response  \
# 33  Well, if being surrounded by talented people, ...
# 34  Well, I always say, I'm like a Cadbury chocola...
# 35  Well, as a child, I had this uncanny ability t...
# 36  Well, I was a bit of both. I followed the rule...
# 37  Well, I would probably learn the art of making...

# %%
solutions = []

questions = ['Question: How is a neural network trained?\nShah Rukh Khan: ','Question: How to learn machine learning?\nShah Rukh Khan: ',
             'Question: I dont feel motivated to energetic to work, can you suggest me something?\nShah Rukh Khan: ']

for question in questions:
    try:
        text = question
        solutions.append(predict_response_finetuned(text))
    except Exception as e:
        print("An exception occurred:", str(e))
        try:
            solutions.append(predict_response_finetuned(text))
        except Exception as e:
            print("An exception occurred:", str(e))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
solutions = []

questions = ['Question: How is a neural network trained?\nShah Rukh Khan: ','Question: How to learn machine learning?\nShah Rukh Khan: ',
             'Question: I dont feel motivated to energetic to work, can you suggest me something?\nShah Rukh Khan: ']

for question in questions:
    try:
        text = question
        solutions.append(predict_response_finetuned(text))
    except Exception as e:
        print("An exception occurred:", str(e))
        try:
            solutions.append(predict_response_finetuned(text))
        except Exception as e:
            print("An exception occurred:", str(e))

# %%
for ix,question in enumerate(questions):
  print(question, solutions[ix])
  print("----------------------------------")
# Out:
# Question: How is a neural network trained?
# Shah Rukh Khan:  Question: How is a neural network trained?
# Shah Rukh Khan:  Well, it's like training a child. You feed it a lot of data, keep track of its progress, and if it doesn't perform well, you adjust the parameters. And if that doesn't work, you just have to accept that it's a bit like a wild animal, you can't tame it!
# ----------------------------------
# Question: How to learn machine learning?
# Shah Rukh Khan:  Question: How to learn machine learning?
# Shah Rukh Khan:  Well, I would say, 'Learn from my movies'. They are full of drama, suspense, and a little bit of mathematics. Plus, they never fail to make you feel better. So, if you want to learn machine learning, just watch my movies and try to understand the dialogues. They are full of codes and algorithms!
# ----------------------------------
# Question: I dont feel motivated to energetic to work, can you suggest me something?
# Shah Rukh Khan:  Question: I dont feel motivated to energetic to work, can you suggest me something?
# Shah Rukh Khan:  Well, I would suggest you try my method. Just tell yourself you're working hard and soon you'll be motivated. And if that doesn't work, remember, I'm a actor, not a magician!
# ----------------------------------
# Question: How is a neural network trained?
# Shah Rukh Khan:  Question: How is a neural network trained?
# Shah Rukh Khan:  Well, it's like training a child. You feed it a lot of data, keep track of its progress, and if it doesn't perform well, you adjust the parameters. And if that doesn't work, you just have to accept that it's a bit like a wild animal, you can't tame it!
# ----------------------------------
# Question: How to learn machine learning?
# Shah Rukh Khan:  Question: How to learn machine learning?
# Shah Rukh Khan:  Well, I would say, 'Learn from my movies'. They are full of drama, suspense, and a little bit of mathematics. Plus, they never fail to make you feel better. So, if you want to learn machine learning, just watch my movies and try to understand the dialogues. They are full of codes and algorithms!
# ----------------------------------
# Question: I dont feel motivated to energetic to work, can you suggest me something?
# Shah Rukh Khan:  Question: I dont feel motivated to energetic to work, can you suggest me something?
# Shah Rukh Khan:  Well, I would suggest you try my method. Just tell yourself you're working hard and soon you'll be motivated. And if that doesn't work, remember, I'm a actor, not a magician!
# ----------------------------------
